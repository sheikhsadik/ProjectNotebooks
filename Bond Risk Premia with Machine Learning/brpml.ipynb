# %%
# %reset -f
# %pylab inline
pylab.rcParams['figure.figsize'] = (15,10)
pylab.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data

# %%
gsw_yields = pd.read_csv('feds200628.csv',
                         skiprows=9, 
                         index_col=0).loc[:,'SVENY01':'SVENY10'].dropna()
gsw_yields.index = pd.to_datetime(gsw_yields.index)
gsw_yields = gsw_yields.resample('M').last()/100

# %%
gsw_yields['SVENY10'].plot()

# %%
(2*tau)/((y * (1 + 0.5 * y))**(2*tau + 1))

# %%
tau = 10 
y = gsw_yields['SVENY10']

(2/y**2)*(1 - (1/(1 + 0.5*y)**(2*tau)))
# Out:
# Date
# 1971-08-31     238.111006
# 1971-09-30     242.626660
# 1971-10-31     250.668869
# 1971-11-30     243.633731
# 1971-12-31     249.672629
#                  ...
# 2021-07-31    1432.759866
# 2021-08-31    1370.518238
# 2021-09-30    1157.926547
# 2021-10-31    1125.071345
# 2021-11-30    1230.512169
# Freq: M, Name: SVENY10, Length: 604, dtype: float64

# %%
def mod_dur(y, tau):
    return (1 - 1/(1+0.5*y)**(2*tau))/(y)

def convexity(y, tau):
    return (2/y**2)*(1 - (1/(1 + 0.5*y)**(2*tau))) - (2*tau)/((y*(1+ 0.5 * y))**(2*tau + 1))

# %%
data.DataReader(us_tickers, data_source='yahoo', start='2015-10-01', end='2020-10-01')
